# %% [markdown]
# # Foundations of Computer Science

# %% [markdown]
# Members of the Group :
# - Bahareh Robaty Shirzad (Student ID: 946887)
# - Samira Doshmankosh  (Student ID: 94683)
# - Setayesh Mohammadi Banadkooki (Student ID: 926072)

# %% [markdown]
# We have to work on the [Trending YouTube](https://drive.google.com/file/d/1VuI1NnPzYlhHIMBy-2nBegFoQTATbf8K/view?usp=sharing) dataset.

# %% [markdown]
# ### Notes
# 1. It is mandatory to use GitHub for developing the project.
# 2. The project must be a jupyter notebook.
# 3. There is no restriction on the libraries that can be used, nor on the Python version.
# 4. All questions on the project must be asked in the Discussion forum on the course website.
# 5. At most 3 students can be in each group. You must create the groups by yourself. You can use the Discussion forum to create the groups.
# 6. You do not have to send me the project before the discussion.
# 7. You do not have to prepare any slides for the discussion.
# 8. You can use AI tools, but you have to describe in the notebook how you have used such tools and you have to show that you have fully understood everything that you have in your project.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Question 1 : Create a single dataframe with the concatenation of all input csv files, adding a column called country

# %%
#since in python synatx \U means unicodeescape, by prefixing the string with an r behind the path, we will specify that-
#-this is a raw string 
CAvideos_path = r"C:\Users\broba\Python-Project\trendingYT\CAvideos.csv.zst"
DEvideos_path = r"C:\Users\broba\Python-Project\trendingYT\DEvideos.csv.zst"
FRvideos_path = r"C:\Users\broba\Python-Project\trendingYT\FRvideos.csv.zst"
GBvideos_path = r"C:\Users\broba\Python-Project\trendingYT\GBvideos.csv.zst"
INvideos_path = r"C:\Users\broba\Python-Project\trendingYT\INvideos.csv.zst"
JPvideos_path = r"C:\Users\broba\Python-Project\trendingYT\JPvideos.csv.zst"
KRvideos_path = r"C:\Users\broba\Python-Project\trendingYT\KRvideos.csv.zst"
MXvideos_path = r"C:\Users\broba\Python-Project\trendingYT\MXvideos.csv.zst"
RUvideos_path = r"C:\Users\broba\Python-Project\trendingYT\RUvideos.csv.zst"
USvideos_path = r"C:\Users\broba\Python-Project\trendingYT\USvideos.csv.zst"

# %%
df1 = pd.read_csv(CAvideos_path)
df2 = pd.read_csv(DEvideos_path)
df3 = pd.read_csv(FRvideos_path)
df4 = pd.read_csv(GBvideos_path)
df5 = pd.read_csv(INvideos_path)
df6 = pd.read_csv(JPvideos_path, encoding='utf-8', encoding_errors = "replace")
df7 = pd.read_csv(KRvideos_path, encoding='utf-8', encoding_errors = "replace")
df8 = pd.read_csv(MXvideos_path, encoding='utf-8', encoding_errors = "replace")
df9 = pd.read_csv(RUvideos_path, encoding='utf-8', encoding_errors = "replace")
df10 = pd.read_csv(USvideos_path)

# %%
df1['country'] = 'Canada'
df2['country'] = 'Germany'
df3['country'] = 'France'
df4['country'] = 'United Kingdom'
df5['country'] = 'India'
df6['country'] = 'Japan'
df7['country'] = 'South Korea'
df8['country'] = 'Mexico'
df9['country'] = 'Russia'
df10['country'] = 'United States'

# %%
final_df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10], ignore_index=True)

# %%
final_df.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828   132239
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622  1634130
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     43420         125882  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1      1688          13030  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 4     21082          85067  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description country
# 0  Eminem's new track Walk on Water ft. Beyoncé i...  Canada
# 1  STill got a lot of packages. Probably will las...  Canada
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...  Canada
# 3  I know it's been a while since we did this sho...  Canada
# 4  🎧: https://ad.gt/yt-perfect\n💰: https://atlant...  Canada

# %%
final_df.to_csv('final_df.csv', index=False)

# %%
print(final_df.dtypes)
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# country                   object
# dtype: object

# %% [markdown]
# ## Question 2 : Extract all videos that have no tag.

# %%
# Method: Using a lambda function to filter videos where the 'tags' column is '[none]'
videos_with_no_tag = final_df[final_df['tags'].apply(lambda x: x == '[none]')]

# Displaying the result
videos_with_no_tag.head()
# Out:
#        video_id trending_date  \
# 41  JwboxqDylgg      17.14.11
# 58  9B-q8h31Bpk      17.14.11
# 78  1UE5Dq1rvUA      17.14.11
# 86  pmJQ4KwliX4      17.14.11
# 98  lHcXhBojpeQ      17.14.11
#
#                                                 title  channel_title  \
# 41  Canada Soccer's Women's National Team v USA In...  Canada Soccer
# 58  John Oliver Tackles Louis C.K. And Donald Trum...       TV Shows
# 78            Taylor Swift Perform Ready For It - SNL     Ken Reactz
# 86  LATEST Q POSTS: ROTHSCHILDS, HOUSE OF SAUD, lL...   James Munder
# 98                   三屆TVB視帝，拋棄10年青梅竹馬髮妻，為娶小三還不惜與母絕交！          明星百曉生
#
#     category_id              publish_time    tags   views  likes  dislikes  \
# 41           17  2017-11-13T05:53:49.000Z  [none]   36311    277        28
# 58           22  2017-11-13T04:49:26.000Z  [none]  106029   1270       101
# 78           24  2017-11-12T05:18:02.000Z  [none]  320964   8069       285
# 86            2  2017-11-12T21:25:40.000Z  [none]  116820   1503       139
# 98           22  2017-11-12T12:49:50.000Z  [none]   88061     47        58
#
#     comment_count                                  thumbnail_link  \
# 41             13  https://i.ytimg.com/vi/JwboxqDylgg/default.jpg
# 58            181  https://i.ytimg.com/vi/9B-q8h31Bpk/default.jpg
# 78            717  https://i.ytimg.com/vi/1UE5Dq1rvUA/default.jpg
# 86           1066  https://i.ytimg.com/vi/pmJQ4KwliX4/default.jpg
# 98             17  https://i.ytimg.com/vi/lHcXhBojpeQ/default.jpg
#
#     comments_disabled  ratings_disabled  video_error_or_removed  \
# 41              False             False                   False
# 58              False             False                   False
# 78              False             False                   False
# 86              False             False                   False
# 98              False             False                   False
#
#                                           description country
# 41  Canada Soccer's Women's National Team face riv...  Canada
# 58                  John Oliver on News, Politics ...  Canada
# 78  Thanks for watching please subscribe and subsc...  Canada
# 86  https://pastebin.ca/3930472\n\nSupport My Chan...  Canada
# 98                                                NaN  Canada

# %% [markdown]
# ## Question 3: For each channel, determine the total number of views

# %%
channels = list(set(final_df['channel_title']))
channels
# Out:
# ['PenzoPozitivo',
#  'Slicky59',
#  'Séan Garnier',
#  'loonatheworld',
#  'Media Muse',
#  'عرب نيوز/ Arab News',
#  'Kinox',
#  'POCKET WIZ【ポケットウィズ】',
#  'runbz',
#  'l Aymane Serhani أيمن سرحاني',
#  'Enamorándonos Programa Amor',
#  'NaVaN Official',
#  'Choco Chip Kookie',
#  'Nihan',
#  'Todo Sobre Exatlon',
#  '革靴吐きたい',
#  '20 Centimos',
#  'Commercial Guys Interactive',
#  'Jean-Noël Bière',
#  'Akhbar Media Maroc - أخبار ميديا ماروك',
#  'Дышите ровно',
#  'abbatstvo',
#  'I Love Cricket',
#  'Promoting Radio',
#  'エルEL',
#  'Telemundo Deportes',
#  'Евгений Григорьев - Жека. Официальный канал',
#  'Bazzi',
#  'TuVi DeSports 2',
#  'Коммерсантъ',
#  'Calem MrNazreen',
#  'Shox Tv',
#  'EL TIO VINES - VIDEOS DE RISA',
#  'StrengGeheim',
#  'WONWOO JUSEYO',
#  'Galich Ida',
#  'Annika ❤❤❤',
#  'Tin Việt Nam',
#  'Rappler',
#  'Eli Ro',
#  'MasterChef 2017',
#  'samir ali',
#  'Чарли Качает',
#  'СВЕТЛАНА ТОКАРСКАЯ',
#  'Eva Lunde Bentley',
#  'Tropicana Canada',
#  '아이유 - IU Fanclub',
#  'DJ- WG',
#  'axrevolution',
#  'K-NEWS',
#  'Chikkaness Ave',
#  'vodu01',
#  'CashmereCatVEVO',
#  'weicki97',
#  'Bratishkin Videos',
#  'El Fedelobo',
#  'Ad Council',
#  'Савельев Андрей',
#  'AZN',
#  'honeyzamm _',
#  'ZDFlachbar',
#  'APRIL',
#  'ANTIZENSURKOALITION',
#  'ソフトテニス ENRICH',
#  'FISHTIQUE',
#  'Umid',
#  'Zap Radio Replay',
#  'Uncle BOBs TV',
#  'zii otb الحزب السعودي',
#  'alanthomasdoyle',
#  'Funhaus',
#  'Top Factory',
#  'EA SPORTS',
#  'Clixoom Science & Fiction',
#  'Discover24',
#  'Zikalooks',
#  'Leyendas Ánima',
#  '電撃ランキング',
#  'HANSE 한세',
#  'BoHpts',
#  'starr jones',
#  'NabalezVEVO',
#  "Futbolero Crack's",
#  'チャンネル人工知能',
#  '스토리바다',
#  'D100 Radio',
#  'Latino Music',
#  'Laura Tagle',
#  'Takis México',
#  'Reyy',
#  'France Inter',
#  'BURNAHI',
#  'Superhero News',
#  'Errant Signal',
#  '世界から見た日本ch 感動大国Japan',
#  'Clickbait Tube',
#  'RED MID',
#  'SS TV TAMIL',
#  'TRUE',
#  'Reynmen',
#  'INSTA-VIDEO',
#  'B Producciones',
#  '아리슈',
#  'Sawt Al Adala صوت العدالة',
#  'Infinity Music',
#  'Rendez-vous en terre inconnue',
#  'Kristen Hancher',
#  '뉴스 Daily News Stories',
#  'Mohamed Le Vagabond',
#  'Global Road Entertainment',
#  'BOCHUMSCHAU',
#  'Jessie & PH',
#  'mai thuy nguyen dang',
#  'Benny Galvin',
#  'MY BTS LOVERS',
#  'Roaming Millennial',
#  'udmtv24',
#  'pattydoo',
#  'Великая Россия',
#  'GOKU EL SUPER',
#  'Глеб Волин',
#  'Колодец под ключ',
#  'Leray Yarel',
#  'LA TEAM CVS',
#  'Maggie Smith Kühn',
#  'Kluna Tik Compilations Channel',
#  'КРЫМ ГЛАЗАМИ МЕСТНЫХ',
#  '김필재 TV',
#  'RNZOnline',
#  'Lab話題の動画',
#  'Myriamprettysecrets',
#  'Kai aus Hannover',
#  'Akhbar I أخبار اليوم',
#  'إفتح قلبك - القناة الرسمية',
#  'OBI',
#  'Eintracht Frankfurt',
#  'hirokuma TV',
#  'fu ck',
#  'Erika Costell',
#  "L'artiste yahya",
#  'Илья Бондарев',
#  'BULL & BULLY',
#  'XYZ ABC',
#  '콘대tv',
#  '雑学魂',
#  'Правовед ТВ',
#  'Internet Historian',
#  'AdcaZz',
#  'Planeta SportTV',
#  'Looskanal',
#  'AmBer KlonDike',
#  'Half Ticket Media',
#  '動物',
#  'ALAS',
#  'Grégoire MORIZET',
#  'Tamika Hall',
#  'that[ざっとん] official',
#  'NADAPRESS',
#  'SANTA SUERTE MUSIC',
#  'Enamorandonos Azteca',
#  'Isas Bloog',
#  'ヒロシちゃんねる',
#  "On n'est pas couché",
#  'The Film Theorists',
#  'ТИЛЭКС',
#  'LyosukeSaitoh official',
#  'GIGA TECH',
#  'Thoisoi',
#  'cllsc',
#  'FRANCE 24',
#  '日本政治の底力',
#  'Крестьянская Жизнь или Фермер Старт',
#  'Moviebox Record Label',
#  'Freestyle Football',
#  'TeichikuMusicChannel',
#  '마스터발그림',
#  'Movie Escenas',
#  'ГРОБ ТОП',
#  '구독해줘영상올릴게',
#  '宇宙の帝王フリーザ様が、ブッタ斬る！',
#  'agn',
#  'Tamosho',
#  'Inna Moll',
#  'The Domestic Geek',
#  'SidTalk',
#  'ManuelRivera11',
#  'DiStory - Дианины Истории',
#  'Chaîne infos déclassifiées ovnis Etc CIDTV',
#  'dinoflask',
#  'Jayo Truth',
#  'スカイピース',
#  'Snapchat RED',
#  'Melle zohra.B',
#  'GOLTV',
#  'CONEXIÓN MX',
#  'Тимка Сурикат',
#  'AB Network',
#  'Channelヒプノシスマイク',
#  'Viacheslav Semenchuk',
#  '신동훈Dick Hunter',
#  'Bethany Mota',
#  'Niloofar Irani',
#  'É TOYS',
#  'スカッと実話ジャパン',
#  'belgrade26',
#  'telblog.net',
#  'Afinka DIY',
#  'Pierre Fouet',
#  'Essential Craftsman',
#  'JukiLop Forever',
#  'News24',
#  'Bödőcs Tibor',
#  'Safia Vendome',
#  'Lazy Masquerade',
#  'Portugal. The Man',
#  'Yuvan Shankar Raja',
#  '장추자',
#  'DylanJT 123',
#  'Hobo Johnson',
#  'Foot Locker',
#  'SAÏKofficiel',
#  '클리어파일',
#  '핫이슈핫news',
#  'Extra DEPORTES',
#  'SimFans.de',
#  '娯楽ニュース',
#  'Larofab',
#  'karam jawanda',
#  'BeingU Music',
#  'Phaentom',
#  'Tv9 Gujarati',
#  '톡톡!! 톡톡!!',
#  'ごみくずサブ',
#  '雑誌 JP',
#  'КАГАНАТ KG',
#  'Computer:Club2',
#  'TV FOX',
#  'ERI Beats',
#  'Yerkir Media TV',
#  'Dream Style Football',
#  'DORALYS BRITTO',
#  'Kowch737',
#  'euronews (en français)',
#  'Tolibjon Safarov',
#  'Alfo Media',
#  'Smokin Rebs',
#  'Marwa Loud',
#  'ItsMyRayeRaye',
#  "Summoner's Inn",
#  'notnotryan',
#  'ПДСМ',
#  'ChroniCars',
#  'LShokeen Films',
#  'The Timeliners',
#  'Martin Garrix',
#  'Brico Dépôt',
#  'Rina',
#  'MOVES LIKE JIMIN',
#  'StanMC',
#  "Le Monde à L'Envers",
#  'Drohnen',
#  'Дарья Каплан',
#  'Bharat Today',
#  'CHA MUSIC',
#  'Adexe & Nau',
#  'Chasseur de Fantômes',
#  'ヨム ヨム',
#  'Ai Sakuranbo',
#  'Luke Price',
#  'VIVA DANCE STUDIO',
#  'Mimi Ar',
#  'Eske Luise',
#  'FoxneoCreation',
#  'BOXDEL',
#  'yasaizukitussan やさいずきつっさん',
#  'АВТОТУТ',
#  'Memes FUT HD',
#  '철영쿤 TV',
#  'Rational Middle',
#  'ValWho Artworks',
#  '띠미 Dimmi',
#  'Mile Kitic',
#  'Boys -WTF',
#  'クリックサッカー',
#  '뚜비창섭',
#  'MiddleKidsVEVO',
#  'ryo tnk',
#  'A-Sketch MUSIC LABEL',
#  'F2Freestylers - Ultimate Soccer Skills Channel',
#  '망개떡 태태',
#  'EvanTubeRAW',
#  'Víctor Lugo',
#  'ハルハルプリンセス',
#  'TBJZL',
#  'AxwellIngrossoVEVO',
#  'TQP channel',
#  'PLAYYANI 플레이애니',
#  'Ball TV',
#  'Андрей Картавцев',
#  "Tia Mowry's Quick Fix",
#  'Febrian erd2',
#  'Brittany Jazz',
#  'いざ鎌倉',
#  'Hyo - Gossip K-poper',
#  '正真正銘のゆいちゃんず。',
#  'NurdRage',
#  'Kollywood Talk',
#  'ロシアンブルー',
#  'France 3 Corse ViaStella',
#  'Lestia Ashdoll',
#  'Wiadomości ze Świata',
#  'ИНТРИГИ - СКАНДАЛЫ - РАССЛЕДОВАНИЯ',
#  'LAF Producciones',
#  'Todos Flotan Pro',
#  'Doozy',
#  'СТАВКА TV',
#  'Ҳикмат нури',
#  '달꽃소녀',
#  'STAR Plus',
#  'Disney Parks',
#  'manna7654',
#  'Ikwansyah 92',
#  'Jorge Leon Oficial',
#  '파스모',
#  'Eat Bulaga!',
#  'TVT Studio',
#  '홍방장',
#  'Trace Cyrus',
#  'Hey! Say! Jump',
#  'M.C.rush',
#  'TANHO TV',
#  'Tisi Schubech',
#  'LBCI Lebanon',
#  'Die Meeries',
#  'Random One',
#  'Кыргызский обзор',
#  'Familia real W',
#  'Addis Konjo',
#  'けやしろー',
#  '野原りん',
#  'DeutschrapCharts TV',
#  'Le Japon en Noir et Blanc✔️',
#  'Good™ Мультики про танки',
#  'Aaj TV',
#  'DjKayzTv',
#  'MySportLiveTV',
#  'PERE BOURRASSE',
#  'The Reel Rejects',
#  'Inaa 144',
#  'El Anonimo SONRIENTE',
#  'Aktuelle News | Österreich',
#  'Cambio de Juego',
#  'Ankit Khola',
#  '에미넌스',
#  'Айтопер',
#  'UzTop TV',
#  'Cam Grande Brune',
#  'КЫЗЫК ТВ',
#  '려리Ryeori',
#  'Magical Nuskhe',
#  'Filmy junction Kannada',
#  'Nick Crompton',
#  'jthepson Pérez',
#  'JW2 Entertainment',
#  'Катя Никольских',
#  'Rodop Music',
#  'Come Back',
#  '부크가 간다_이뉴스TV',
#  'Amaury et Quentin',
#  'TNT América Latina',
#  'LORDAN Play',
#  'チキンチャンネル',
#  'Famous Celebrities Snaps',
#  'emi lia',
#  'DreadMarIVEVO',
#  'Политика Путина',
#  'Əliəşrəf',
#  'きらきらアフロ Pham',
#  'La PolitiKK',
#  'Thad Broman',
#  'Telugu Boxoffice TV',
#  'SERVIMAT',
#  'The Atlantic',
#  'NoodleVlogs',
#  'Bendita Lucha Libre',
#  'Mucho para ver',
#  'taalk com',
#  'TheEllenShow',
#  'Daniel Howell',
#  'Adam',
#  'Samia & Nouveautés',
#  'La Banana Rancia',
#  'КриптоЛихорадка',
#  'DontTrustTheRabbit',
#  'ANTENNE BAYERN',
#  'fanslokotv',
#  'EsKay',
#  'hanan beauty',
#  '이슈와반응 issue&reaction',
#  'MoonSub Jin',
#  '010-2896-3010 양지암',
#  'RH Noticias',
#  'Tistory News',
#  'さぼりｃｈ',
#  'Duncan Sinfield',
#  'michele corrado',
#  'E Z',
#  'LeBwa | World of Tanks',
#  'kimmycup22793',
#  'DuSale',
#  'Камила Алиева',
#  'Sunu Tele Senegal',
#  'Jordan Dzib',
#  'Tomatos',
#  'Pompiers de Paris',
#  'Suzuka Toho',
#  'ABS-CBN Entertainment',
#  'Silvio Gamer',
#  'jun임재준',
#  'jettaboy2931',
#  'Delhi Darpan TV',
#  'Аватария Official',
#  'Hybrid Network',
#  'fejevi fejevi',
#  'Clown Show',
#  'Breaking News Today - Official Channel',
#  'スポーツ大全集',
#  'Jayaraj G Nath',
#  '무비 키즈',
#  'Anfisa Nava',
#  'Christian Dumon',
#  'Camera Café',
#  'The Youman Show - EL CANAL DE LAS LOCURAS',
#  'NewTV Патруль',
#  '投稿専用ザK',
#  'Fav Movies',
#  'Lloyd 2.0',
#  '옴니버스',
#  'WeatherTech',
#  'Marbouha TV مربوحة',
#  'Masha Create',
#  'Play 2 tv',
#  'Comedy Caches',
#  'optimisster',
#  'DOTV KOREA [이수현]',
#  'Maxik',
#  'ラファエル・クッキング Raphael cooking',
#  'PEXUS',
#  'Michael uzumaki',
#  'Sherlina Nym',
#  'HeyUGuys',
#  'News7 Tamil',
#  'Le club',
#  'Tio Joda',
#  'Schloss Webstein',
#  'mike ishikawa_No.2',
#  'Фильмы и Сериалы Дизель Студио',
#  'Superflame',
#  'laabuelitamarthita48',
#  '14Dimension Enterprise',
#  'Optimus Bee',
#  'Status',
#  'Focus Features',
#  'Radio 538',
#  'Daym Drops',
#  'Drew Cruz',
#  'Royal Update',
#  'Tellement Miam',
#  '金スマYOSHIKI',
#  '소녀시대의 모든 것',
#  '유 유',
#  'ぽく ぽく',
#  'Alejandro Zúñiga EN VIVO',
#  'Xari',
#  'Bri Tu Mirada Méndez LM',
#  "' 옌응",
#  'Kbiz Sky News',
#  'Сергей Алексашенко',
#  'Lekko Nie Będzie',
#  'Bóng Đá Trực Tiếp',
#  'Lisa del Piero',
#  'Cinema News Updates',
#  'CCTV中文国际',
#  'Clash of Clans',
#  'てきとう太郎',
#  'Nicki Swift',
#  'Girlyalex83',
#  'akkun 2001',
#  'Exatlon México TV',
#  'Tajik Kelin',
#  'jamesblakeproduction',
#  'Antonio Lara',
#  'ハイサイ探偵団の休日',
#  'Лагаут С:',
#  'ElAbril',
#  'blondinka iztokyo',
#  'The Humanist Report',
#  'Süßigkeiten Unfall',
#  'Joordy',
#  'Уральский трубник',
#  '연합뉴스Digital',
#  'Baeluis †',
#  'TV СИЛА В ПРАВДЕ Регионы России',
#  'IGN News',
#  'MOVIEあにまる',
#  'Meханик Life',
#  'Die Crew',
#  'Dz reality',
#  '영국남자 Korean Englishman',
#  'Mia and me Deutsch',
#  'Best of Simpsons Characters',
#  'La Vanguardia',
#  'Unitezz Media Official',
#  'Fights without rules Лучшие Моменты и Бои!',
#  'ღ비니',
#  'CamilaCabelloVEVO',
#  'Spachi',
#  'Henrique Cantilho',
#  'JTBC News',
#  'LIVE 101.5 Phoenix',
#  'Sibiria Рыбалка и Охота',
#  'Нохчо К1ант',
#  '佐藤 そると は 鼻のJK',
#  'Актуальный новости каждый день',
#  'KL Channel',
#  'Roberto Guevara',
#  'ToriKellyVEVO',
#  'Chloe x Halle',
#  'さる～いん',
#  'GAZgroup',
#  'Novedades Exatlon',
#  'El Universal Video',
#  'RozhinTV',
#  'le dragon fps',
#  'Good Mythical MORE',
#  'PARA TV',
#  'Дмитрий Левандовский',
#  '이상호',
#  'Гузель Уразова',
#  'Jumia Cameroun',
#  'Sebastián Villalobos',
#  'TusPelotas',
#  'SpaceStar',
#  'Ara i Aquí',
#  'FBI사무실',
#  'ZolTV NET',
#  'Bigflo & Oli - FANS',
#  'Comfy.ua | Бытовая техника для жизни',
#  'Bachelor Nation on ABC',
#  'Amazing Changes',
#  'PATO VIRAL',
#  '柴田富男',
#  'Beatz and Bluntz',
#  '2EURO MUSIC',
#  'Eric Strebel',
#  'Валерий Пякин Видеоархив',
#  'DanielSosa16',
#  '닷페이스 .FACE',
#  'SoFiA',
#  'Andreea Petcu',
#  'FULAB',
#  'exo_ddulbaek',
#  'Super.kg',
#  'EDGARIUS',
#  'darriem love',
#  'Kisu',
#  'HIDDEN STAGE',
#  '7-Second Riddles',
#  '듀륭ʕ·ᴥ·ʔ',
#  'Javier VAZQUEZ',
#  '쵸파TV - 원피스 토론 채널',
#  'Jimena Hernandez C',
#  '女人我最大',
#  'Tahapan Nime',
#  'Andrew M',
#  'Freeform',
#  'BlackPinkxXxBlinks',
#  'rusreklama',
#  'Innie Official',
#  'Alex & PJ',
#  'TEAM SOREL',
#  'JayJay제이제이',
#  'Techno',
#  'Naka Sun',
#  'FunTime Приколы',
#  '14,999,999 views',
#  'Роман Томера',
#  'Mac Gyver',
#  '世界まる見えNTV',
#  'inBet',
#  'N24 Doku',
#  'Cody & Wyatt',
#  'ぷろたん日記',
#  'Fred Hermel',
#  '코즐러Kozzler',
#  '욘 바인첼',
#  'JessieJVEVO',
#  'Fynn Kliemann Musik',
#  '【公式】DMMぱちタウンch',
#  'Football Goals HD',
#  'Anna Kurkurina',
#  'indiglamour',
#  'UnErase Poetry',
#  'Coco',
#  '日本ニュース速報',
#  'Rolanda Nicholas',
#  'Dave Gaming',
#  'La Nueva Dimensión',
#  'NumberOne Kyrgyzstan',
#  'LA NETA',
#  'Apixelados',
#  'さむらい情報局',
#  'ワールド芸能サテライト',
#  'らじおらじおチャンネル',
#  'GitcheGumme',
#  'Samara Redway',
#  'les inratables de samira',
#  'JackIncongruente',
#  'Martinique la 1ère',
#  'AFINO',
#  'Energie FM - Das Fanradio,von Fans für Fans',
#  'Chinnathirai Seithigal',
#  '元奨励会員アユムの将棋実況',
#  'News India 24',
#  'MyAnielo',
#  'TV Clips & Sendungen',
#  'Gerencia360TV',
#  'NoelGallagherVEVO',
#  'Borsh Story',
#  'Lo Viral Ahora',
#  'RollingStone Japan',
#  'Nathan C',
#  'Annas Home of Love',
#  'Maytrixx',
#  'Mehmet Dokuyucu',
#  'Nacho y Rodri',
#  'PTC PUNJABI GOLD',
#  'Korean ENT',
#  'Pierre Magdziak',
#  'misha robaqidze',
#  'marcador3final',
#  'inCycle',
#  'MADうんこちゃん',
#  'Cosmic Channel',
#  'CLUB TV',
#  'Guardian News',
#  '樋口楓【にじさんじ公式】',
#  'Pietronila TV',
#  'Dima Ermuzevich',
#  'HeraiTV',
#  'Philipp',
#  'Schräg',
#  'iling show',
#  'Calvin Klein',
#  'Psico FaRy',
#  'Vic Dibitetto',
#  'KLEFLIX',
#  'smiechawaTV',
#  'theMeatly',
#  'I News',
#  'Heftig',
#  'Amour, Gloire et Beauté',
#  '한닝[워너블',
#  'Ksesha Meow',
#  'Avxry',
#  'Overwatch Moments - Gaming Curios',
#  'Utopia Show',
#  'Game Of Thrones',
#  'Зробский MMA',
#  'Virus Music',
#  'Trucks TV l Тракс ТВ',
#  'ミラクルミラクル Official YouTube Channel',
#  'КАК - Константин ака Костян',
#  'MusicLover',
#  'Overdrive Productions',
#  'Arica Hutton',
#  'PO N',
#  'У Жоржа',
#  'KipMooreVEVO',
#  'Seoulite Station',
#  'JuankiBoom - Minecraft Roleplay',
#  'Орифлэйм Россия',
#  'Radio Plus',
#  'Усман Баратов',
#  'Chu의목츄리',
#  'larsandersen23',
#  'BeautyMarieB',
#  'Grimis™',
#  'EVA GUESS',
#  'Film Annonce',
#  'Bts Army',
#  'Dcarreras Chihuahua',
#  'El Cardenal Gas Das',
#  'Svasta Svasta',
#  'BongoBoulevard',
#  'soberwhat',
#  'Kenzie Dysli',
#  '最近話題のスポーツ',
#  'PxndxCD',
#  'Cloth Map',
#  'HispanTV',
#  'Conexiones Correo',
#  'The Russian Channel',
#  'Manga One',
#  'BILLUR TV',
#  'Nadia Ustinova',
#  'Discovery Science France',
#  'OneRepublic',
#  'vegaltachannel',
#  'شوف ديزاد Chouf Dz I',
#  'JayJay Jackpot',
#  'phoenix',
#  'Monkey Android',
#  '악어의사생활',
#  'Construction Channel Fuximux',
#  '442oons',
#  'Neymagico',
#  'ALEX ZURDO MUSIC',
#  'ilyan anis',
#  'Patrice Nouma',
#  '秋せつら',
#  'MediaKooraHD-TV+3',
#  'Tele-Series Somos Fans',
#  'Yukiko Hideyoshi',
#  'Maugly',
#  'ViscaBarca',
#  '오프쇼어TV',
#  '武田邦彦・中野信子チャンネル',
#  'Golden LifeTV 黄金人生TV',
#  'To7Fa Tube',
#  'ХОЛМИ',
#  'algo sobre telenovelas algo sobre telenovelas',
#  'This is Хорошо',
#  'DisneyChannelLAVEVO',
#  'Elton John',
#  'Zaay Mint',
#  'Ambition Music',
#  'Rasmus Raita',
#  'SKEPTA',
#  'Krya Krya',
#  'УМНЫЕ НЕ МОЛЧАТ',
#  'Futbolero2012HD1',
#  'SowDred',
#  'Super',
#  '실시간 NEWS',
#  "JC's Workshop",
#  'Schlager Musik',
#  '더깊이10',
#  'Crazy TV',
#  "文茜的世界周報 Sisy's World News",
#  'Bad Bunny',
#  'BosseAxel',
#  'Manuel B',
#  'موقع الواجهة',
#  'La Manche Libre',
#  'Marco Ponce',
#  'Anaki Abo',
#  'misaki',
#  'Kalyn Nicholson',
#  "Les Princes Et Princesses De L'Amour",
#  'UberHaxorNova',
#  'Ahmed Lndy',
#  '호이짜TV',
#  'ファン速報プロ野球',
#  '짐니1',
#  'Palomitas y Flow',
#  'винди вапрол',
#  'sumi asai',
#  'Yoan',
#  'PunjabKesari TV',
#  '姫 ch',
#  'Evangelista Samuel Hernandez',
#  '글로벌디펜스뉴스',
#  'Футбольный Клуб Оренбург',
#  'Дневник Roxie',
#  'US Military Power',
#  'BEYBLADE BURST DEUTSCHLAND Official',
#  '내키 G',
#  'Médias Magazine',
#  'Ksenia Vasilieva',
#  '홍차紅茶',
#  "observe'em",
#  'Nadorcity-Official',
#  'Rock Entertainment TV',
#  'ENAMORANDONOS Chismes y mas',
#  'NADEGE CANDLE',
#  'ГОРОД ГРЕХОВ',
#  'ClubdeprensaElPais',
#  'Jigli & Khajur - Official',
#  'PREDICAS CRISTIANAS TV',
#  'ABIZ ENT BUZZ',
#  'health & life',
#  '롤즘',
#  'Sachin Tendulkar',
#  'namanlies',
#  'Lotucias',
#  'Foydali uz',
#  'ТВОИ НОВОСТИ',
#  'Prime News Overseas',
#  'horin* 호린',
#  'Pantene Türkiye',
#  'Glamour Paris',
#  'Salvage Hunters',
#  'Joe Santagato',
#  'luisito Hdzz',
#  'MundoManitas',
#  'Atlanta Journal-Constitution',
#  'けもみみおーこく国営放送',
#  'Mercury News',
#  'Fox Hockey',
#  'Вера Жукова',
#  'Fabrice FLORENT - Histoires de Darons',
#  'carlos eduardo braca ortega',
#  'Thomas Cyrix',
#  'факты и истории',
#  '빡센TV',
#  'Ben Sitz',
#  "L'Opinion",
#  '어른이 TV',
#  'EBSCulture (EBS 교양)',
#  'mp3quran Website',
#  'Liga Mexicana del Pacífico',
#  'Wefere',
#  'Это [Интересно]',
#  'Lances HD',
#  'BabyZone',
#  'Phan',
#  'Heartland',
#  'Rote Nelke',
#  'GingerKidzUnited',
#  '炎の論客',
#  'Vinny Piano',
#  'MCDAVO',
#  'Hip Rap',
#  'Dua Lipa',
#  'Максим Темченко',
#  "LosVaM's",
#  'Anna Ceres Bar',
#  'Chasse88',
#  'Barcenilla',
#  'エンタメすぷりんぐ',
#  '윤그린 YOONGREEN',
#  'Ring Bimmer',
#  'Cameron Philip',
#  'Neztor Mvl Oficial',
#  'この素晴らしいアニメに祝福を!',
#  'Sports Station TV',
#  'Idols K-pop',
#  'مزمز كورة',
#  'Zee Music Marathi',
#  '芸能エンタメDX',
#  'Kanto Malagasy',
#  'Nik Nocturnal',
#  'queensoo',
#  '국민TV 뉴스K',
#  'Consejero Espiritual',
#  'Irma Veronica Flores Flores',
#  'EL Vielman',
#  'Filmy Monk',
#  'Miranda Sings',
#  'Mikegamer 777',
#  "Sam's Officiel DZ",
#  'King Dm',
#  "Its' Mamix",
#  'ROBINHO',
#  'RED21',
#  'Olivier Seban',
#  'Nesrine Turkiye',
#  '매쓰메카수학학원',
#  'ILYA STREKAL',
#  'Tez',
#  'Only News 24x7',
#  'OfficialFifthHarmony',
#  '!島ちゃん',
#  'Yo Amo El Futbol',
#  'Ракета t8',
#  'KADHAFI MBUMBUDI',
#  'jongens en co',
#  'san-therm',
#  'ガキ使',
#  'zeetv',
#  'ElSmosh',
#  'Pa Sports Live',
#  'プレーン / plain YouTuber',
#  'Татар-информ',
#  'Jenny Nicholson',
#  'The Last Leg',
#  'Hige',
#  'SANDALWOOD REVIEWS',
#  'SOMOS RAP',
#  'Chris Cross',
#  'Irman',
#  'Алёшкин картон',
#  'Ana Mojica Fitness',
#  'Privateclub Records',
#  'EntretenimientoTV',
#  'Linus Tech Tips',
#  'Football4Broz',
#  'ANTOINE FOMBONNE',
#  'Sexy Konna',
#  'Van Tu',
#  '서울시(Seoul City)',
#  'catgil2',
#  'Mademoizelle Margaux',
#  'Saskatchewan Rush',
#  'Marie Vwy',
#  'Hyukヒョク',
#  'Дневник Карины СТРАШИЛКИ',
#  '音楽映像 - マーベラス公式チャンネル',
#  'ZetasWorks',
#  '버팔로',
#  'shaycarl',
#  'KHON2 News',
#  'arigustv',
#  'German Ultras',
#  'Anirban Dasgupta',
#  'ロバート秋山の「クリエイターズ・ファイル」',
#  'Mohamed Bouaouina',
#  'Godrules',
#  'Ingrid Nilsen',
#  'Kid World',
#  'Проверь все сам!',
#  'NuoViso.TV',
#  'Страшилки от Дядюшки',
#  'Evolution Pro',
#  'Halil İbrahim Karaoğlan',
#  'Multimedia 7',
#  'Alican Ağırman',
#  'First Take',
#  'Samovar Rus',
#  'CHECHEN WHATSAPP 3',
#  '파쿠H&M TV',
#  'Профессор Преображенский',
#  'FRSermon Center',
#  'MatSch',
#  'Pupsi',
#  'FACE',
#  'Laupok',
#  'THE MAGNUM',
#  'Mad Mag',
#  'Gera MXM',
#  'Arabische Straße - شارع العرب',
#  'ALL SPORTS',
#  'Cheat Codes',
#  '100 Percent Sketch Comedy Show',
#  'News 18 Tamilnadu',
#  '100/ Potins GALSEN',
#  'Charles Jakubowski',
#  'JarJar Abrams',
#  'Rommel Alarcon Sanchez 3.0',
#  'Eruma Saani',
#  'Kim Flores',
#  'T-Series Apna Punjab',
#  'Nalita',
#  'Stephane Deraffin',
#  'The Average-Man',
#  'So Geht Das',
#  'AMBIENT',
#  'Scarce',
#  'La Débande',
#  'Avances de Narcoseries 2',
#  'Александра Киевская',
#  '목사이기방',
#  'LouisaJohnsonVEVO',
#  'ManicStPreachersVEVO',
#  'ᄋᄇ',
#  'Les Minikeums',
#  'momo kids',
#  'NBC',
#  'radio days',
#  'YOONGREEN윤그린',
#  'Mira One',
#  'INFORMACIONES 5 ESTRELLAS',
#  '스윗박스',
#  '연합뉴스TV',
#  'PopBuzz',
#  'Susy MX',
#  'Popcorn with Peter Travers',
#  'Heinz Hammer',
#  'ReggaetonFlow',
#  'AfD-Fraktion im Bundestag',
#  'Iconoclaste',
#  'ШКОЛА НАСТРОЕНИЯ',
#  'Павел Блюденов',
#  'Mithra Creation',
#  'ネタパレ',
#  'анти биго.тв',
#  'Choquillo',
#  'Congo Lipanda TV',
#  'Zastępca Poncjusza Pijaka',
#  'レイターズ',
#  'Aeroplan Canada',
#  'ДВА РОЯЛЯ',
#  'Nezah',
#  'RizaNovaUZ',
#  'Team 10 Radio',
#  'Anzu Kitty',
#  '푹 (pooq)',
#  'CBRT Trends and News',
#  'Magali Bertin - Beauté Blog',
#  ...]

# %%
views = final_df.groupby('channel_title')['views'].sum()
views.head()
# Out:
# channel_title
# ! 세상에 무슨일이                3942977
# !!8時だよ面白ネタ大集合               50207
# !BTS・TWICE まとめ               7310
# !Los amorosos Virales¡       6069
# !t Live                    240038
# Name: views, dtype: int64

# %% [markdown]
# ## 4. Save all rows with disabled comments and disabled ratings, or that have video_error_or_removed in a new dataframe called excluded, and remove those rows from the original dataframe.

# %%
exclusion_condition = (
    (final_df['comments_disabled'] == True) &  
    (final_df['ratings_disabled'] == True)     
) | (final_df['video_error_or_removed'] == True)

# %%
excluded = final_df[exclusion_condition].copy()

# %%
rows_to_remove = excluded.index

# %%
final_df = final_df.drop(rows_to_remove, axis=0)

# %%
final_df.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828   132239
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622  1634130
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     43420         125882  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1      1688          13030  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 4     21082          85067  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description country
# 0  Eminem's new track Walk on Water ft. Beyoncé i...  Canada
# 1  STill got a lot of packages. Probably will las...  Canada
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...  Canada
# 3  I know it's been a while since we did this sho...  Canada
# 4  🎧: https://ad.gt/yt-perfect\n💰: https://atlant...  Canada

# %%
print(f"Rows in 'excluded' DataFrame: {len(excluded)}")
# Out:
# Rows in 'excluded' DataFrame: 2620

# %%
print(f"Original Row Count (before exclusion): {len(excluded) + len(final_df)}")
# Out:
# Original Row Count (before exclusion): 375942

# %%
print(f"Rows remaining in 'final_df': {len(final_df)}")
# Out:
# Rows remaining in 'final_df': 373322

# %% [markdown]
# ## 5. Add a like_ratio column storing the ratio between the number of likes and dislikes

# %%
#For videos with zero dislikes, the ratio is undefined and therefore set to NaN.
final_df['like_ratio'] = final_df.apply(
    lambda r: r['likes'] / r['dislikes']
    if pd.notna(r['dislikes']) and r['dislikes'] > 0
    else np.nan,
    axis=1
)

final_df['no_dislikes'] = final_df['dislikes'].isna() | (final_df['dislikes'] == 0)

# %%
final_df[['likes', 'dislikes', 'like_ratio', 'no_dislikes']].head()
# Out:
#      likes  dislikes  like_ratio  no_dislikes
# 0   787425     43420   18.135076        False
# 1   127794      1688   75.707346        False
# 2   146035      5339   27.352500        False
# 3   132239      1989   66.485168        False
# 4  1634130     21082   77.513044        False

# %%
final_df[final_df['no_dislikes'] == True][
    ['likes', 'dislikes', 'like_ratio']
].head()
# Out:
#      likes  dislikes  like_ratio
# 67       0         0         NaN
# 161    187         0         NaN
# 173      0         0         NaN
# 235     88         0         NaN
# 271      1         0         NaN

# %%
final_df.to_csv(
    r"C:\Users\broba\Python-Project\outputs\final_df.csv",
    index=False,
    encoding="utf-8-sig"
)

# %% [markdown]
# ## 6. Cluster the publish time into 10-minute intervals (e.g. from 02:20 to 02:30)

# %%
# Convert the column to datetime objects
final_df['publish_time'] = pd.to_datetime(final_df['publish_time'])

# remove the timezone (I checked it in the file, it was the same in all countries)
final_df['publish_time'] = final_df['publish_time'].dt.tz_localize(None)

# round down to the nearest 10 minutes. Example: 02:23:00 becomes 02:20:00
interval_start = final_df['publish_time'].dt.floor('10min')

# create "Start-End" string format
# adds 10 minutes to the start time to get the end time
final_df['interval_10min'] = (
    interval_start.dt.strftime('%H:%M') + "-" + 
    (interval_start + pd.Timedelta(minutes=10)).dt.strftime('%H:%M')
)

print(final_df[['publish_time', 'interval_10min']].head())
# Out:
#          publish_time interval_10min
# 0 2017-11-10 17:00:03    17:00-17:10
# 1 2017-11-13 17:00:00    17:00-17:10
# 2 2017-11-12 19:05:24    19:00-19:10
# 3 2017-11-12 18:01:41    18:00-18:10
# 4 2017-11-09 11:04:14    11:00-11:10

# %% [markdown]
# ## 7. For each interval, determine the number of videos, average number of likes and of dislikes.

# %%
interval_stats = final_df.groupby('interval_10min').agg(
    num_videos=('video_id', 'count'),
    avg_likes=('likes', 'mean'),
    avg_dislikes=('dislikes', 'mean')
).reset_index() #to reset 'interval_10min' from being index (was converted by groupby) into a flat table
print(interval_stats.head())
# Out:
#   interval_10min  num_videos     avg_likes  avg_dislikes
# 0    00:00-00:10        2913  60951.483350   3787.232750
# 1    00:10-00:20        1522  22553.870565   1437.457293
# 2    00:20-00:30        1248  21258.370192   1066.330128
# 3    00:30-00:40        1625  36604.352000    949.439385
# 4    00:40-00:50        1283  41770.614186   1889.012471

# %% [markdown]
# ## 8. For each tag, determine the number of videos. Notice that tags contains a string with several tags.

# %%
# splits and explodes tags
tags_series = final_df['tags'].str.split('|').explode()

#deleting none tags
tags_series = tags_series.replace('', None).dropna()

#remove spaces/quotation and lowercase the strings
tags_series = tags_series.str.strip().str.strip('"').str.lower()

#number of videos for each tag
tag_counts = tags_series.value_counts(sort=False)
print("\n first 20 tags with the number of videos they repeated in:\n")
print(tag_counts.head(20))
# Out:
#  first 20 tags with the number of videos they repeated in:
#
# tags
# eminem                         675
# walk                           227
# on                             496
# water                          573
# aftermath/shady/interscope     127
# rap                           5476
# plush                           19
# bad unboxing                    20
# unboxing                      1385
# fan mail                        39
# idubbbztv                       42
# idubbbztv2                      33
# things                         112
# best                          2520
# packages                        13
# plushies                        22
# chontent chop                    9
# racist superman                122
# rudy                           261
# mancuso                        210
# Name: count, dtype: int64

# %% [markdown]
# ## 9. Find the tags with the largest number of videos.

# %%
# first I decided to delete [none] tag
tags_series_new = tags_series.replace('[none]', None).dropna()

# Then to sort the tags
tag_counts_sorted = tags_series_new.value_counts()

print(tag_counts_sorted.head())
# Out:
# tags
# funny     17344
# comedy    15701
# 2018      11402
# news       9199
# music      8262
# Name: count, dtype: int64

# %% [markdown]
# ## 10. For each (tag, country) pair, compute average ratio likes/dislikes.

# %%
df_pairs = final_df[['tags', 'country', 'like_ratio']].copy()

df_pairs['tags'] = df_pairs['tags'].str.split('|')
df_pairs = df_pairs.explode('tags')

# clean & split tags
df_pairs['tags'] = df_pairs['tags'].str.strip().str.strip('"').str.lower()


# remove empty, [none], nan tags
df_pairs = df_pairs.dropna(subset=['tags']) #remove real Nulls (NaN/None)
df_pairs = df_pairs[df_pairs['tags'] != ''] #remove empty strings ('')
df_pairs = df_pairs[df_pairs['tags'] != '[none]'] #remove the "[none]" tags

# calculating the average of like_ratio For each (tag, country) pair 
result = df_pairs.groupby(['tags', 'country'])['like_ratio'].mean().reset_index()

#to make columns by their names to have a clear output
result.columns = ['tag', 'country', 'average_ratio']

print(result.head(20))
# Out:
#                                                   tag      country  \
# 0                           ! banii i-au luat mintile      Germany
# 1                                                  !!       France
# 2                                                  !!       Mexico
# 3                                     !! *me bloquea*       Mexico
# 4                                                 !!!       Mexico
# 5                                                !!!!       France
# 6                             !00% sketch comedy show       Russia
# 7                                             !t live  South Korea
# 8                                   # carlosvideostar       Mexico
# 9   # einen schönen tag wünschen# einen schönen so...      Germany
# 10                                    # ssc scam 2018        India
# 11                            # ssc scam protest 2018        India
# 12                                          # コリアンタウン        Japan
# 13                                          ##cutting       Russia
# 14                                        ##free view       Russia
# 15                                 ##jessi##cantora##       Russia
# 16                                                 #0       Mexico
# 17                                                #02       France
# 18                                                #03      Germany
# 19                                               #044       Mexico
#
#     average_ratio
# 0        6.222739
# 1       12.452875
# 2       38.081559
# 3       65.260870
# 4       12.952381
# 5        5.000000
# 6             NaN
# 7      912.398601
# 8       60.160000
# 9             NaN
# 10      35.552176
# 11      35.552176
# 12       8.393258
# 13      56.714286
# 14            NaN
# 15       5.900000
# 16      69.747005
# 17      71.863309
# 18      98.460835
# 19      88.750000

# %% [markdown]
# ## 11. For each (trending_date, country) pair, the video with the largest number of views

# %%
q11_result= final_df.loc[ final_df.groupby( ['trending_date' , 'country'])['views'].idxmax()] 
q11_result= q11_result.sort_values(by='views',ascending= False) 

print( "top videos per date and country:")
display(q11_result[['trending_date', 'country', 'title', 'views']].head())
# Out:
# top videos per date and country:
#        trending_date         country  \
# 150857      18.07.04  United Kingdom
# 150657      18.06.04  United Kingdom
# 150453      18.05.04  United Kingdom
# 150256      18.04.04  United Kingdom
# 150060      18.03.04  United Kingdom
#
#                                                     title      views
# 150857  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  424538912
# 150657  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  413586699
# 150453  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  402650804
# 150256  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  392036878
# 150060  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  382401497

# %% [markdown]
# ## 12. Divide trending_date into three columns: year, month, day

# %%
final_df[ 'trending_date'] = pd.to_datetime( final_df['trending_date'] , format='%y.%d.%m')

final_df['year'] = final_df['trending_date'].dt.year
final_df['month'] = final_df['trending_date'].dt.month
final_df['day'] = final_df['trending_date'].dt.day

print( "columns created successfully!")
display(final_df[['trending_date', 'year', 'month', 'day']].head())
# Out:
# columns created successfully!
#   trending_date  year  month  day
# 0    2017-11-14  2017     11   14
# 1    2017-11-14  2017     11   14
# 2    2017-11-14  2017     11   14
# 3    2017-11-14  2017     11   14
# 4    2017-11-14  2017     11   14

# %% [markdown]
# ## 13. For each (month, country) pair, the video with the largest number of views

# %%
#we group by 'month' and 'country' ( created in q12 ), find the index of max views, and select those rows

q13_result= final_df.loc[ final_df.groupby( [ 'month','country']) ['views'].idxmax()] 
#sort the result by month to make it easier to read
q13_result= q13_result.sort_values(by=['month'])

print("top videos per month and country:")
display(q13_result[['month','country','title', 'views']])
# Out:
# top videos per month and country:
#         month         country  \
# 11214       1          Canada
# 92853       1          France
# 51930       1         Germany
# 173405      1           India
# 264769      1          Mexico
# ...       ...             ...
# 259064     12          Mexico
# 299087     12          Russia
# 224092     12     South Korea
# 130634     12  United Kingdom
# 341174     12   United States
#
#                                                     title      views
# 11214   Bruno Mars - Finesse (Remix) [Feat. Cardi B] [...   43067983
# 92853   Bruno Mars - Finesse (Remix) [Feat. Cardi B] [...   37728802
# 51930   Bruno Mars - Finesse (Remix) [Feat. Cardi B] [...   37728802
# 173405     Taylor Swift - End Game ft. Ed Sheeran, Future   42019590
# 264769  Bruno Mars - Finesse (Remix) [Feat. Cardi B] [...   31680160
# ...                                                   ...        ...
# 259064  YouTube Rewind: The Shape of 2017 | #YouTubeRe...  100912384
# 299087  YouTube Rewind: The Shape of 2017 | #YouTubeRe...   52611730
# 224092  YouTube Rewind: The Shape of 2017 | #YouTubeRe...  113876217
# 130634  YouTube Rewind: The Shape of 2017 | #YouTubeRe...  169884583
# 341174  YouTube Rewind: The Shape of 2017 | #YouTubeRe...  149376127
#
# [77 rows x 4 columns]

# %% [markdown]
# ## 14. Read all json files with the video categories

# %%
import json
import os

folder_path = r"C:\Users\broba\Python-Project\trendingYT" 
category_data = {}

try:
    all_files = os.listdir(folder_path)
    for filename in all_files:
        if filename.endswith('_category_id.json'):
            country_code = filename.split('_')[0]
            full_path = os.path.join(folder_path, filename)
            
            with open(full_path, 'r', encoding='utf-8') as f:
                data = json.load(f)
                valid_ids = [int(item['id']) for item in data['items']]
                category_data[country_code] = valid_ids
                print(f"✅ Loaded: {country_code}")
except FileNotFoundError:
    print(f"❌ Error: Folder not found at {folder_path}")
# Out:
# ✅ Loaded: CA
# ✅ Loaded: DE
# ✅ Loaded: FR
# ✅ Loaded: GB
# ✅ Loaded: IN
# ✅ Loaded: JP
# ✅ Loaded: KR
# ✅ Loaded: MX
# ✅ Loaded: RU
# ✅ Loaded: US

# %% [markdown]
# ## 15. For each country, determine how many videos have a category that is not assignable.

# %%
# --- STRATEGY EXPLANATION ---
# The CSV file uses full country names (e.g., 'France'), while JSON filenames use 2-letter codes (e.g., 'FR').
# 1. The dataset contains non-standard names (e.g., 'Great Britain' vs. ISO standard 'United Kingdom') which causes errors in automated libraries.
# 2. Since the scope is limited to only 10 countries, a manual dictionary ensures 100% accuracy without adding external dependencies.

country_mapper = {
    'United States' : 'US',
    'United Kingdom' : 'GB' ,
    'Germany' : 'DE',
    'Canada' : 'CA',
    'France' : 'FR',
    'Russia' : 'RU',
    'Mexico' : 'MX',
    'South Korea': 'KR',
    'Japan' : 'JP',
    'India' : 'IN'
}

print(f"{'country':<20} | {'Bad Categories Count'}") 
print("_" * 45) 

for country_name in final_df['country'].unique():
    country_code = country_mapper.get(country_name)

    if country_code and country_code in category_data:
        valid_ids = category_data[country_code]
        country_df = final_df[final_df['country'] == country_name]
        
        bad_videos = country_df[~country_df['category_id'].isin(valid_ids)]
        print(f"{country_name:<20} | {len(bad_videos)}")
    else:
        print(f"{country_name:<20} | Data not found (Code: {country_code})")
# Out:
# country              | Bad Categories Count
# _____________________________________________
# Canada               | 74
# Germany              | 256
# France               | 114
# United Kingdom       | 90
# India                | 105
# Japan                | 18
# South Korea          | 288
# Mexico               | 252
# Russia               | 1541
# United States        | 0
